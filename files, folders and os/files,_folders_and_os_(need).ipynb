# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders and OS (Need)</span></div>

# %% [markdown]
# ## 1 Important concepts

# %% [markdown]
# ### 1.1 Path

# %% [markdown]
# ### 1.2 More about relative paths

# %%
# Your code here

# %% [markdown]
# ### 1.3 Path separator

# %%
# Your code here

# %% [markdown]
# ### Text files vs Binary files

# %% [markdown]
# ### Extentions

# %%
# Your code here

# %% [markdown]
# ### 1.4 Opening and closing files

# %%
with open('spectrum-01.txt','r') as file:
    file_content = file.read()
    
print(file_content)
# Out:
# Light Intensity, Ch A vs Actual Angular Position, Run #4
# Actual Angular Position (  )	Light Intensity, Ch A ( % max )
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.3
# 0.000	-0.2
# 0.000	-0.2
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.004	-0.1
# 0.010	-0.2
# 0.018	-0.2
# 0.024	-0.3
# 0.029	-0.3
# 0.033	-0.3
# 0.036	-0.2
# 0.039	-0.1
# 0.043	-0.1
# 0.047	-0.1
# 0.053	-0.1
# 0.060	-0.1
# 0.066	-0.1
# 0.069	-0.1
# 0.073	-0.1
# 0.076	-0.1
# 0.079	-0.1
# 0.081	-0.1
# 0.082	-0.1
# 0.083	-0.2
# 0.083	-0.2
# 0.086	-0.2
# 0.090	-0.2
# 0.095	-0.2
# 0.100	-0.3
# 0.103	-0.3
# 0.104	-0.2
# 0.105	-0.3
# 0.107	-0.2
# 0.110	-0.2
# 0.115	-0.1
# 0.122	-0.2
# 0.128	-0.1
# 0.134	-0.2
# 0.139	-0.1
# 0.144	-0.2
# 0.150	-0.2
# 0.157	-0.2
# 0.164	-0.2
# 0.170	-0.3
# 0.175	-0.3
# 0.180	-0.2
# 0.185	-0.2
# 0.191	-0.1
# 0.195	-0.1
# ...

# %%
text = 'Far out in the uncharted backwaters of the unfashionable end of the western spiral arm of the Galaxy lies a small unregarded yellow sun.\nOrbiting this at a distance of roughly ninety-two million miles is an utterly insignificant little blue green planet whose ape-descended life forms are so amazingly primitive that they still think digital watches are a pretty neat idea.'

with open('my-text-once.txt', 'w') as file:
    file.write(text)

# %%
with open('my-text-lines.txt', 'w') as file:
    for line in text.splitlines():
        file.writelines(line)

# %% [markdown]
# ## 2 Playing with the OS

# %% [markdown]
# ### 2.1 Some packages

# %%
import os
import glob
import shutil

# %% [markdown]
# ### 2.2 OS safe paths

# %%
path = os.path.join('.', 'all-data', 'sg-data', 'data-01.txt')
print(path)
# Out:
# .\all-data\sg-data\data-01.txt

# %% [markdown]
# ### 2.3 Creating folders

# %%
os.mkdir('people')

for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# Creating people\Jonh
# Creating people\Paul
# Creating people\Ringo

# %% [markdown]
# ### 2.4 Checking for existence

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    try:
        os.mkdir(path)
        print(f'Creating {path}')
    except FileExistsError:
        print(f'{path} already exists; skipping creation.')
# Out:
# people\Jonh already exists; skipping creation.
# people\Paul already exists; skipping creation.
# people\Ringo already exists; skipping creation.

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    if os.path.exists(path):
        print(f'{path} already exists; skipping creation.')
    else:
        os.mkdir(path)
        print(f'Creating {path}')
# Out:
# people\Jonh already exists; skipping creation.
# people\Paul already exists; skipping creation.
# people\Ringo already exists; skipping creation.

# %% [markdown]
# ### 2.5 Copying files

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path_to_destination = os.path.join('people', person)
    shutil.copy('sp2273_logo.png', path_to_destination)
    print(f'Copied file to {path_to_destination}')
# Out:
# Copied file to people\Jonh
# Copied file to people\Paul
# Copied file to people\Ringo

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path_to_imgs = os.path.join('people', person, 'imgs')
    if not os.path.exists(path_to_imgs):
        os.mkdir(path_to_imgs)

    current_path_of_logo = os.path.join('people', person, 'sp2273_logo.png')
    new_path_of_logo = os.path.join('people', person, 'imgs', 'sp2273_logo.png')

    shutil.move(current_path_of_logo, new_path_of_logo)
    print(f'Moved logo to {new_path_of_logo}')
# Out:
# Moved logo to people\Jonh\imgs\sp2273_logo.png
# Moved logo to people\Paul\imgs\sp2273_logo.png
# Moved logo to people\Ringo\imgs\sp2273_logo.png

# %% [markdown]
# ### 2.6 Listing files

# %%
glob.glob('*')
# Out:
# ['files,_folders_and_os_(need).ipynb',
#  'my-text-lines.txt',
#  'my-text-once.txt',
#  'people',
#  'sp2273_logo.png',
#  'spectrum-01.txt']

# %%
glob.glob('peo*')
# Out:
# ['people']

# %%
glob.glob('peo*/*')
# Out:
# ['people\\Jonh', 'people\\Paul', 'people\\Ringo']

# %%
glob.glob('people/**', recursive=True)
# Out:
# ['people\\',
#  'people\\Jonh',
#  'people\\Jonh\\imgs',
#  'people\\Jonh\\imgs\\sp2273_logo.png',
#  'people\\Paul',
#  'people\\Paul\\imgs',
#  'people\\Paul\\imgs\\sp2273_logo.png',
#  'people\\Ringo',
#  'people\\Ringo\\imgs',
#  'people\\Ringo\\imgs\\sp2273_logo.png']

# %%
glob.glob('people/**/*.png', recursive=True)
# Out:
# ['people\\Jonh\\imgs\\sp2273_logo.png',
#  'people\\Paul\\imgs\\sp2273_logo.png',
#  'people\\Ringo\\imgs\\sp2273_logo.png']

# %% [markdown]
# ### 2.7 Moving about

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Yun Na\\onedrive\\documents\\github\\learning-portfolio-pohyunna\\files, folders and os'

# %%
os.chdir('people/Ringo')

# %% [markdown]
# ### 2.8 Extracting Info

# %%
path = 'people/Ringo/imgs/sp2273_logo.png'
filename = path.split(os.path.sep)[-1]
extension = filename.split('.')[-1]
print(filename, extension)
# Out:
# people/Ringo/imgs/sp2273_logo.png png

# %%
path = 'people/Ringo/imgs/sp2273_logo.png'

# %%
os.path.split(path)
# Out:
# ('people/Ringo/imgs', 'sp2273_logo.png')

# %% [markdown]
# ### 2.9 Deleting stuff

# %%
shutil.rmtree('C:\\Users\\Yun Na\\OneDrive\\Documents\\GitHub\\learning-portfolio-pohyunna\\files, folders and os\\people\\Ringo')

# %% [markdown]
# ## Exercise 7 :  The OS is my oyster

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Yun Na\\onedrive\\documents\\github\\learning-portfolio-pohyunna\\files, folders and os'

# %%
os.chdir('C:\\Users\\Yun Na\\OneDrive\\Documents\\GitHub\\learning-portfolio-pohyunna\\files, folders and os')

# %%
os.mkdir('python_today')

# %%
os.chdir('C:\\Users\\Yun Na\\OneDrive\\Documents\\GitHub\\learning-portfolio-pohyunna\\files, folders and os\\python_today')

os.getcwd()
# Out:
# 'C:\\Users\\Yun Na\\OneDrive\\Documents\\GitHub\\learning-portfolio-pohyunna\\files, folders and os\\python_today'

# %%
directories = []
number =1
while number < 51:
    directories.append(f'new_directory_{number:02d}')
    number +=1

for directory in directories:
    os.mkdir(directory)

# %%
number = 1
while number < 51:
    os.rmdir(f'new_directory_{number:02d}')
    number +=2

# %%
os.listdir()
# Out:
# ['new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_10',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_20',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_30',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_40',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48',
#  'new_directory_50']

# %%
number = 10
while number < 51:
    os.rename(f'new_directory_{number:02d}', f'haha_{number:02d}')
    number +=10

# %%
number = 5
while number < 51:
    if os.path.exists(f'haha_{number:02d}'):
        print(f'haha_{number:02d} already exists')
    else:
        os.mkdir(f'haha_{number:02d}')
        print(f'Creating haha_{number:02d}')
    number += 5
# Out:
# Creating haha_05
# haha_10 already exists
# Creating haha_15
# haha_20 already exists
# Creating haha_25
# haha_30 already exists
# Creating haha_35
# haha_40 already exists
# Creating haha_45
# haha_50 already exists

# %%
os.listdir()
# Out:
# ['haha_05',
#  'haha_10',
#  'haha_15',
#  'haha_20',
#  'haha_25',
#  'haha_30',
#  'haha_35',
#  'haha_40',
#  'haha_45',
#  'haha_50',
#  'new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48']

# %%
source = os.path.join("C:\\Users\\Yun Na\\OneDrive\\Documents\\GitHub\\learning-portfolio-pohyunna\\files, folders and os\\sp2273_logo.png")
destination = []
number = 5
while number < 51:
    destination.append(f'haha_{number:02d}')
    number += 5

for dest in destination:
    shutil.copy(source, dest)

# %%
glob.glob('haha*/*')
# Out:
# ['haha_05\\sp2273_logo.png',
#  'haha_10\\sp2273_logo.png',
#  'haha_15\\sp2273_logo.png',
#  'haha_20\\sp2273_logo.png',
#  'haha_25\\sp2273_logo.png',
#  'haha_30\\sp2273_logo.png',
#  'haha_35\\sp2273_logo.png',
#  'haha_40\\sp2273_logo.png',
#  'haha_45\\sp2273_logo.png',
#  'haha_50\\sp2273_logo.png']

# %% [markdown]
# ## Exercise 8 :  Tidying a collaboration

# %%
os.chdir('C:\\Users\\Yun Na\\OneDrive\\Documents\\GitHub\\learning-portfolio-pohyunna\\files, folders and os\\os-collaboration-exercise-data')

# %%
monthdictionary = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}


def rename_my_file(x):
    month = (f'{x[0]}{x[1]}{x[2]}')
    monthdictionary[month]
    x = x.replace(month, monthdictionary[month])
    x = x.replace('_', '-')
    return(x)

rename_my_file('feb-08_singapore.txt')
# Out:
# '02-08-singapore.txt'

# %%
x = 'oct-08_singapore.txt'

month = (f'{x[0]}{x[1]}{x[2]}')
monthdictionary[month]
x = x.replace(month, monthdictionary[month])
x = x.replace('_', '-')
x
# Out:
# '10-08-singapore.txt'

# %%
names = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

for name in names:
    rename_my_file(name)
    print(rename_my_file(name))
# Out:
# 10-08-singapore.txt
# 07-10-cairo.txt
# 05-15-dhaka.txt
# 05-13-cairo.txt
# 10-21-cairo.txt
# 01-10-singapore.txt
# 06-20-tokyo.txt
# 08-06-jakarta.txt
# 12-21-karachi.txt
# 01-01-tokyo.txt

# %%
allthefiles = glob.glob('*.txt')
for files in allthefiles:
    rename_my_file(files)
    os.rename(files, rename_my_file(files))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 3
#       1 allthefiles = glob.glob('*.txt')
#       2 for files in allthefiles:
# ----> 3     rename_my_file(files)
#       4     os.rename(files, rename_my_file(files))
#
# Cell In[32], line 11, in rename_my_file(x)
#       9 def rename_my_file(x):
#      10     month = (f'{x[0]}{x[1]}{x[2]}')
# ---> 11     monthdictionary[month]
#      12     x = x.replace(month, monthdictionary[month])
#      13     x = x.replace('_', '-')
#
# KeyError: '01-'

# %%
countries = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for country in countries:
    countryfolder = os.path.join(country)
    if not os.path.exists(countryfolder):
        os.mkdir(countryfolder)

# %%
cairofiles = glob.glob('*cairo*')

for files in cairofiles:
    destination = ('C:\\Users\\Yun Na\\OneDrive\\Documents\\GitHub\\learning-portfolio-pohyunna\\files, folders and os\\os-collaboration-exercise-data\\Cairo')
    shutil.copy(files, destination)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[70], line 5
#       3 for files in cairofiles:
#       4     destination = ('C:\\Users\\Yun Na\\OneDrive\\Documents\\GitHub\\learning-portfolio-pohyunna\\files, folders and os\\os-collaboration-exercise-data\\Cairo')
# ----> 5     shutil.copy(files, destination)
#
# File ~\miniconda3\lib\shutil.py:417, in copy(src, dst, follow_symlinks)
#     415 if os.path.isdir(dst):
#     416     dst = os.path.join(dst, os.path.basename(src))
# --> 417 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     418 copymode(src, dst, follow_symlinks=follow_symlinks)
#     419 return dst
#
# File ~\miniconda3\lib\shutil.py:254, in copyfile(src, dst, follow_symlinks)
#     252     os.symlink(os.readlink(src), dst)
#     253 else:
# --> 254     with open(src, 'rb') as fsrc:
#     255         try:
# ...

# %%
allfiles = glob.glob(f'*{countries}*')

for files in allfiles:
    destination = os.path.join(files)
    shutil.move(files, destination)
# Out:
# ['01-01-manila.txt',
#  '01-01-osaka.txt',
#  '01-02-cairo.txt',
#  '01-02-karachi.txt',
#  '01-02-manila.txt',
#  '01-03-cairo.txt',
#  '01-03-jakarta.txt',
#  '01-03-karachi.txt',
#  '01-03-shanghai.txt',
#  '01-04-cairo.txt',
#  '01-04-jakarta.txt',
#  '01-04-karachi.txt',
#  '01-04-manila.txt',
#  '01-05-cairo.txt',
#  '01-05-melbourne.txt',
#  '01-05-osaka.txt',
#  '01-06-jakarta.txt',
#  '01-06-karachi.txt',
#  '01-06-melbourne.txt',
#  '01-07-cairo.txt',
#  '01-08-cairo.txt',
#  '01-08-manila.txt',
#  '01-08-osaka.txt',
#  '01-08-tokyo.txt',
#  '01-09-cairo.txt',
#  '01-09-karachi.txt',
#  '01-09-manila.txt',
#  '01-09-melbourne.txt',
#  '01-10-jakarta.txt',
#  '01-10-karachi.txt',
#  '01-10-shanghai.txt',
#  '01-11-cairo.txt',
#  '01-11-manila.txt',
#  '01-11-melbourne.txt',
#  '01-12-cairo.txt',
#  '01-12-jakarta.txt',
#  '01-12-karachi.txt',
#  '01-12-melbourne.txt',
#  '01-12-osaka.txt',
#  '01-12-tokyo.txt',
#  '01-13-cairo.txt',
#  '01-13-jakarta.txt',
# ...

# %%
allfolders = glob.glob(f'{countries}')
allfolders
# Out:
# []

# %%
os.chdir('C:\\Users\\Yun Na\\OneDrive\\Documents\\GitHub\\learning-portfolio-pohyunna\\files, folders and os\\os-collaboration-exercise-data')
